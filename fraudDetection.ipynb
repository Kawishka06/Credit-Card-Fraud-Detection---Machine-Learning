# %% [markdown]
# 1) Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import gridspec

# %% [markdown]
# 2) Import the dataset

# %%
df=pd.read_csv("creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# 03) Analyze class distributions

# %%
fraud_data=df[df['Class']==1]
valid_data=df[df['Class']==0]
outliers=len(fraud_data)/float(len(valid_data))
print('Valid Transactions: {}'.format(len(df[df['Class'] == 0])))
print('Fraud Cases: {}'.format(len(df[df['Class'] == 1])))
print('Outlier Fraction: ',outliers)
# Out:
# Valid Transactions: 284315
# Fraud Cases: 492
# Outlier Fraction:  0.0017304750013189597

# %% [markdown]
# 4)Explaining the transactions

# %%
print("Details of Valid Transactions: ")
valid_data.Amount.describe()
# Out:
# Details of Valid Transactions:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
print("Details of Fraudulent Transactions: ")
fraud_data.Amount.describe()
# Out:
# Details of Fraudulent Transactions:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
correlation_matrix= df.corr()
fig = plt.figure(figsize = (12, 9))
sns.heatmap(correlation_matrix, vmax = .8, square = True)
plt.show()

# %% [markdown]
# 6)Preparing the data set

# %%
X=df.drop(['Class'],axis=1) #remove the target column to keep only the inputs
Y=df["Class"] #Selects the column as the target variable
print(X.shape)
print(Y.shape)

xData=X.values
yData=Y.values

from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(
        xData, yData, test_size = 0.2, random_state = 42)
# Out:
# (284807, 30)
# (284807,)

# %% [markdown]
# 7) Building the Model

# %%
from sklearn.ensemble import RandomForestClassifier

rfc=RandomForestClassifier() #Initializes a new instance
rfc.fit(xTrain,yTrain) # Train the RandomForest Classifier model on training data

yPred=rfc.predict(xTest) #Use the trained model to predict the target labels for the test data and store them

# %% [markdown]
# 8) Finally evaluate the model

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef,confusion_matrix
model_accuracy= accuracy_score(yTest,yPred)
model_precision=precision_score(yTest,yPred)
model_recall=recall_score(yTest,yPred)
model_f1score=f1_score(yTest,yPred)
model_matthews_corrcoef=matthews_corrcoef(yTest,yPred)

print("Model Evaluation Using Several Metrics")
print("Accuracy: ",model_accuracy)
print("Precision: ",model_precision)
print("Recall: ",model_recall)
print("F1 Score: ",model_f1score)
print("Matthews Correlation Coefficient: ",model_matthews_corrcoef)
# Out:
# Model Evaluation Using Several Metrics
# Accuracy:  0.9995786664794073
# Precision:  0.9743589743589743
# Recall:  0.7755102040816326
# F1 Score:  0.8636363636363636
# Matthews Correlation Coefficient:  0.8690748763736589

# %%
conf_matrix = confusion_matrix(yTest, yPred)
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Reds",
            xticklabels=['Normal', 'Fraud'], yticklabels=['Normal', 'Fraud'])
plt.title("Confusion Matrix for Fraud Detection")
plt.xlabel("Predicted Class")
plt.ylabel("True Class")
plt.show()
